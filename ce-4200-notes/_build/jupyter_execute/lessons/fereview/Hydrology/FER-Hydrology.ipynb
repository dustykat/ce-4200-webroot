# %% [markdown]
# # 16. FER - Hydrology (Runoff and Seepage)
#
# :::{admonition} Contributors
# TBA
# :::

# %% [markdown]
# ## Readings
#
# 1. [FER-HydrologyAndHydraulicsPractice.pdf](http://54.243.252.9/ce-4200-webroot/ce-4200-notes/lessons/fereview/Hydrology/FER-HydrologyAndHydraulicsPractice.pdf)
# 2. [Diagnostic quiz in Lindeburg FE Civil Review preceding chapters 9-11](http://54.243.252.9/ce-4200-webroot/ce-4200-notes/lessons/fereview/Hydrology/CE4101-Hydrology-2017-10.pdf)
#
# ## Videos
#
# 1. [Civil FE/PE Exam – Hydraulics & Hydrology – Best Drainage Analysis Method for Pond Storage](https://www.youtube.com/watch?v=-Vn37socO8Q)
# 2. [FE Exam Concepts - Darcy's Law - Groundwater Flow - Civil & Environmental FE](https://www.youtube.com/watch?v=YvTV5TmtQOU)
# 3. [Hydrology Topic 2-3-5 Precipitation Data Analysis / Point Precipitation / Mean Areal Rainfall](https://www.youtube.com/watch?v=B6xu6Ea_DB0)
# 4. [Hydrology, Hydraulics, and Groundwater Quiz with Explained Solutions (Cleveland)](https://youtu.be/tJWV_Uxv-jM)
# 5. [Lindeburg Quiz P1-Solution](https://youtu.be/8eNB6CKf9S0)
# 6. [Lindeburg Quiz P2-Solution](https://youtu.be/RfuNCZA0QEE)
# 7. [Lindeburg Quiz P3-Solution](https://youtu.be/qqx9Vu_n9ec)
# 8. [Lindeburg Quiz P4-Solution](https://youtu.be/e-rRGHKfzn8)
# 9. [Lindeburg Quiz P5-Solution](https://youtu.be/cTiEVGrdm9s)
# 10. [Lindeburg Quiz P6-Solution](https://youtu.be/agYS7wsVh-4)
# 11. [Lindeburg Quiz P7-Solution](https://youtu.be/q32973xh-dU)
# 12. [Lindeburg Quiz P8-Solution](https://youtu.be/okMVYZdVNk0)
# 13. [Lindeburg Quiz P9-Solution](https://youtu.be/7DTtxhdHwgo)
# 14. [Lindeburg Quiz P10-Solution](https://youtu.be/srp54kuOagQ)

# %% [markdown]
# ## Problem 59 (NCEES Practice Exam Manual)
#
# For a new development of 75 acres (0.117 $~mi^2$), the peak runoff for a 25-year storm of 360 *cfs* is to be limited to 180 *cfs* by use of a detention basin.  The total runoff $Q$ is 3.4 inches.  Assume Type II rainfall. Using the TR55 Method and the figure below, the preliminary estimate of storage volume (ac-ft) is most nearly:

# %% [markdown]
# ![](TR55-chart.png)
#
# A. 0.07<br>
# B. 0.11<br>
# C. 3.80<br>
# D. 5.94<br>

# %%
# solution - find total runoff in acre feet
Q=3.4 #in
A=75.0 #acres
volRunoff=Q*(1/12)*A
# use required peak discharge ratio 180/360 to find storage to runoff ratio from chart
qratio = 180/360
# look up storage to runoff ratio in chart
print("Discharge Ratio : ",qratio)
# Out:
# Discharge Ratio :  0.5

# %% [markdown]
# look up storage to runoff ratio in chart
#
# ![](TR55-chart-annotate.png)

# %%
stor2runoff = 0.28
# compute required storage
basinStorage = stor2runoff*volRunoff
print("Runoff Volume : ",volRunoff," acre-ft ")
print("Discharge Ratio : ",qratio)
print("Storage to Runoff Ratio : ",stor2runoff)
print("Basin Storage Required : ",basinStorage," acre-ft ")
# Out:
# Runoff Volume :  21.25  acre-ft
# Discharge Ratio :  0.5
# Storage to Runoff Ratio :  0.28
# Basin Storage Required :  5.95  acre-ft

# %% [markdown]
# Computed answer is 5.92 acre-ft, choose "D"

# %% [markdown]
# ## Problem 61 (NCEES Practice Exam Manual)
#
# Four monitoring wells - A,B,C,and D - lie equidistant (200~ft) form a fifth well E.  The depth to the water table is measured at each well and is shown below.  The datum for the top of casing (TOC) for each well is equal to the five wells.  Groundwater moves in which direction from point E?
#
# ![](WellField.png)
#
# (A) South <br>
# (B) East <br>
# (C) North <br>
# (D) West

# %%
# solution - the values given are depth to water (DTW) so we subtract from TOC to get head
toc = 500 # any number would be fine
dtwA = 105
dtwB = 100
dtwC = 105
dtwD = 110
dtwE = 105
hA = toc-dtwA
hB = toc-dtwB
hC = toc-dtwC
hD = toc-dtwD
hE = toc-dtwE
print("head A : ",hA)
print("head B : ",hB)
print("head C : ",hC)
print("head D : ",hD)
print("head E : ",hE)
# Out:
# head A :  395
# head B :  400
# head C :  395
# head D :  390
# head E :  395

# %% [markdown]
# now draw equipotentials, and find flowline
#
# ![](WellFieldAnnotate.png)
#
# Best answer is A (South)

# %% [markdown]
# ## Problem
#
# A 3.2-inch storm is uniformly distributed over a 95 acre watershed. The NRCS Curve Number for the watershed is CN = 78. The anticipated watershed runoff is about
#
# (A)  8.0 acre-feet <br>
# (B)  9.0 acre-feet <br>
# (C) 10.0 acre-feet <br>
# (D) 11.0 acre-feet

# %% [markdown]
# ## Section End
#
# **[FER-Hydrology Preview](http://54.243.252.9/ce-4200-webroot/ce-4101/Hydrology(NewEngine).pdf)**
#
# [FER-HydrologyAndHydraulicsPractice-AnswerKey.pdf](http://54.243.252.9/ce-4200-webroot/ce-4200-notes/lessons/fereview/Hydrology/FER-HydrologyAndHydraulicsPractice-AnswerKey.pdf)
